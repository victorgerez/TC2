# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II - R4052 - 2023
#
# # Trabajo Semanal 4
# #### Autor: Victor Rodolfo Gerez (146.766-9)

# %% [markdown]
# ***
# A partir de la siguiente plantilla:
# <br>
#
# <br>
#
# ![imagen-4.png](attachment:imagen-4.png)
# <br>
#
# ![imagen-5.png](attachment:imagen-5.png)
# <br>
#
# <br>
#
# **1)** Obtener la transferencia de **máxima planicidad** del filtro requerido.
#
# **2)** Obtener el diagrama de polos y ceros, y un bosquejo de la respuesta en frecuencia. Compare el diagrama de polos y ceros con el del filtro pasabajo prototipo.
#
# **3)** Implementar el circuito **normalizado** con estructuras pasivas. (Puede utilizar dispositivos activos para separar secciones).
#
# **4)** Reemplace los inductores en las estructuras pasivas mediante el *GIC de Antoniou*, en la configuración que considere más apropiada.
#
# **5)** Proponga una red que se comporte igual a la hallada en 4) pero con resistores, capacitores y opamps.
#
# **Bonus**:
#
#     +10 💎 Simulación numérica y circuital.
#     +10 🍺 Presentación en jupyter notebook

# %% [markdown]
# ---------------
# # 1)
#
# ### Normalizo plantilla con $\,\Omega'_\omega=2 \pi f_p = 2 \pi \, 40 kHz \,\Rightarrow\, \boxed{\omega_{p_N}=1} \,\land\, \boxed{\omega_{s_N}=0,25}$
# #### (en adelante se trabaja con valores normalizados omitiendo el respectivo subíndice)
#
# ### Transformo a pasabajos prototipo aplicando núcleo de transformación: $K(p)=s=\frac 1 p \,\,\Rightarrow\,\, \omega=\frac 1 \Omega$
# ### siendo:
# ### $s=\sigma + j \omega \,$ (pasaaltos objetivo)
# ### $p=\Sigma+j\Omega \,$ (pasabajos prototipo)
# <br>
#
# ### $\,\Rightarrow\, \Omega_p=\frac 1 {\omega_p}=1$
# ### $\,\Rightarrow\, \Omega_s=\frac 1 {\omega_s}=4$
# <br>
#
# ---------------
#
# ### Sintetizo pasabajos prototipo (máxima planicidad):
#
# ### Obtengo $\epsilon \, \rightarrow \, \epsilon^2 = 10^{\frac{\alpha_{máx}}{10}}-1 = 10^{0,1}-1 \approx 0,259 \,\Rightarrow\, \boxed{\epsilon \approx 0,509}$
# ### Obtengo $n \, \rightarrow \, n = \frac 1{2} log_{\omega_s}(\frac{10^{\frac{\alpha_{mín}}{10}}-1)}{\epsilon^2}) \,\, \Rightarrow \,\, n = \frac 1{2} log_2 (\frac{10^3-1}{0,259}) \,\, \Rightarrow \,\, n \approx 2,978 \,\, \Rightarrow \,\, n\in\mathbb{Z} \,\rightarrow\,\boxed{n=3}$
# <br>
#
# ### Para trabajarlo como Butterworth, renormalizo con $\,\Omega''_\omega=\omega_B=\epsilon^{-\frac 1 n}=\epsilon^{-\frac 1 3}\approx 1,252$
# ### $\, \Rightarrow \, |T_3(j\Omega)|^2 = \frac 1{1+ \Omega^{6}}  \, \rightarrow \,(\epsilon=1)$
# ### Ceros: orden 3 en el infinito
# ### Polos (tomo los 3 del semiplano izquierdo):
# ### - radio unitario: $\Omega_0=1$
# ### - equiespaciados en ángulo: $\frac \pi n=\frac \pi 3$, un polo en eje $\Sigma$ y dos polos complejos conjugados estarán en: $\, \alpha =\pm \frac \pi 3$
# ### $\,\Rightarrow\, p_1: \, p=-1 \,\,\,\,\land\,\,\,\, p_{2;3}: \, p=e^{\pm j\frac \pi 3}$
# ### $\Rightarrow Q=\frac 1{2\cos (\alpha)}=1$
# <br>
#
# ## $\,T_{{LP}_N}(p)=\frac {\Omega_0}{p+\Omega_0} \, \frac {\Omega_0^2}{p^2+\frac {\Omega_0}Q p+\Omega_0^2}=\frac 1{p+1} \, \frac 1{p^2+p+1}$
#
# ### Desnormalizo la renormalización con:  $\,\Omega''_\omega=\omega_B=\epsilon^{-\frac 1 3}\,$ siendo $p_N=\frac p{\epsilon^{-\frac 1 3}}\,$ o visto de otra forma $\Omega_0=\epsilon^{-\frac 1 3}$
#
# ## $\,T_{LP}(p)=\frac {\Omega_0}{p+\Omega_0} \, \frac {\Omega_0^2}{p^2+\frac {\Omega_0}Q p+\Omega_0^2}=\frac {\epsilon^{-\frac 1 3}}{p+\epsilon^{-\frac 1 3}} \, \frac {\epsilon^{-\frac 2 3}}{p^2+\epsilon^{-\frac 1 3}p+\epsilon^{-\frac 2 3}}$
# <br>
#
# ---------------
#
# ### Transformo a pasaaltos objetivo aplicando núcleo de transformación: $K(s)=p=\frac 1 s$
# ## $\,T_{LP}|_{p=\frac 1 s}=T_{{HP}_N}(s)=\frac {\epsilon^{-\frac 1 3}}{\frac 1 s+\epsilon^{-\frac 1 3}} \, \frac {\epsilon^{-\frac 2 3}}{{\frac 1 s}^2+\epsilon^{-\frac 1 3}\frac 1 s+\epsilon^{-\frac 2 3}}$
# ## $\boxed{T_{{HP}_N}(s)=\frac s{s+\omega_0} \, \frac {s^2}{s^2+\frac {\omega_0}Q s+\omega_0^2}=\frac s{s+\epsilon^{\frac 1 3}} \, \frac {s^2}{s^2+\epsilon^{\frac 1 3}s+\epsilon^{\frac 2 3}}=\frac {s^3}{s^3+2 \epsilon^{\frac 1 3} s^2 + 2 \epsilon^{\frac 2 3} s + \epsilon}}$
# <br>
#
# ### Finalmente desnormalizo con $\,\Omega'_\omega= 2 \pi \, 40 kHz\,\,$ siendo $\,s_N=\frac s{\Omega'_\omega}\,\,$ o visto de otra forma $\,\omega_0=\epsilon^{\frac 1 3} \Omega'_\omega$
# ## $\boxed{T_{HP}(s)=\frac s{s+\omega_0} \, \frac {s^2}{s^2+\frac {\omega_0}Q s+\omega_0^2}=\frac s{s+\epsilon^{\frac 1 3} \Omega'_\omega} \, \frac {s^2}{s^2+\epsilon^{\frac 1 3} \Omega'_\omega s+\epsilon^{\frac 2 3} {\Omega'_\omega}^2}=\frac {s^3}{s^3+2 \epsilon^{\frac 1 3} \Omega'_\omega s^2 + 2 \epsilon^{\frac 2 3} {\Omega'_\omega}^2 s + \epsilon \, {\Omega'_\omega}^3}}$

# %% [markdown]
# -----------------
# ## **Simulación de función transferencia pasaaltos desnormalizada con Python**

# %% [markdown]
# Cargo librerías:

# %%
# módulos numéricos y de funciones científicas
import numpy as np
from scipy import signal as sig
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import matplotlib as mpl

# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys

# %% [markdown]
# Configuro gráficos:

# %%
plt.figure(1)
plt.close(1)

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# %% [markdown]
# Simulo:

# %%
epsilon = 0.509
erc = np.cbrt(epsilon) # epsilon^(1/3)
norma = 2*np.pi*40000

num = np.array([1,0,0,0]) 
den = np.array([1,2*erc*norma,2*erc*erc*norma*norma,epsilon*norma*norma*norma])

TS = sig.TransferFunction(num,den)

_, axes_hdl = bodePlot(TS)

plt.sca(axes_hdl[0])
#plt.ylim([-120,0])

plt.gca

pzmap(TS)

GroupDelay(TS)

plt.show()

# %% [markdown]
# <br>
#
# ### Detalle de $\omega_p\,$ y $\, \omega_s$
# <img src="Simulaciones/transf_desnor_wp.png" align="center"/>
# <img src="Simulaciones/transf_desnor_ws.png" align="center"/>

# %% [markdown]
# ---------------
# # 2)
#
# ### Ceros: en el infinito
# ### Polos:
# ### $s^3+2 \epsilon^{-\frac 1 3} s^2 + 2 \epsilon^{-\frac 2 3} s + \frac 1 \epsilon = 0 \,$
# ### Tanteo posibles raíces mediante teorema de Gauss $\, \Rightarrow \, \boxed {p_1: \, s=-\epsilon^{-\frac 1 3}}$
# ### Factorizo la transferencia dividiéndola por el binomio $s+\epsilon^{-\frac 1 3}$ (raíz hallada) mediante regla de Ruffini:
# ### $(s^3+2 \epsilon^{-\frac 1 3} s^2 + 2 \epsilon^{-\frac 2 3} s + \frac 1 \epsilon) \div (s+\epsilon^{-\frac 1 3}) = s^2+ \epsilon^{-\frac 1 3} s + \epsilon^{-\frac 2 3}$
# ### Hallo raíces de dicha cuadrática:
# ### $\frac {-b\pm \sqrt{b^2-4 a c}}{2 a} \, \rightarrow \,  \boxed {p_{2;3}: \, s=-\frac {\epsilon^{-\frac 1 3}} 2 \pm j \sqrt 3 \frac {\epsilon^{-\frac 1 3}} 2 }$
# <br>
#
# ---------------
#
# ### Respuesta en frecuencia:
# ### $T(s)|_{s=j\omega}=T(j\omega)=\frac {\frac 1 \epsilon}{-j\omega^3-2 \epsilon^{-\frac 1 3} \omega^2 + 2 \epsilon^{-\frac 2 3} j\omega + \frac 1 \epsilon} = \frac {\frac 1 \epsilon}{-2 \epsilon^{-\frac 1 3} \omega^2  + \frac 1 \epsilon +j(-\omega^3 + 2 \epsilon^{-\frac 2 3} \omega)}$
# ### $\boxed{\left|{T(j\omega)}\right|= \frac 1{\sqrt{1+\epsilon^2 \omega^6}}}$
# ### Si $\omega = 0 \, \Rightarrow \, |{T(j\omega)}|= 1 = 0 dB$
# ### Si $\omega = \epsilon^{-\frac 1 3} \, \Rightarrow \, |{T(j\omega)}|= \frac 1 {\sqrt 2} = -3 dB$
# ### Si $\omega \rightarrow \infty \, \Rightarrow \, |{T(j\omega)}|= 0$
# <br>
#
# ### $\phi [T(j\omega)]=\phi[N(j\omega)]-\phi[D(j\omega)]=\arctan(\frac {\Im[N(j\omega)]}{\Re[N(j\omega)]})-\arctan(\frac {\Im[D(j\omega)]}{\Re[D(j\omega)]})=0-\arctan(\frac {-\omega^3 + 2 \epsilon^{-\frac 2 3} \omega)}{-2 \epsilon^{-\frac 1 3} \omega^2  + \frac 1 \epsilon})$
# ### Y como $\, \arctan(x)=-\arctan(-x)\,$ por ser función impar:
# ### $\boxed{\phi [T(j\omega)]=\arctan(\frac {\omega^3 - 2 \epsilon^{-\frac 2 3} \omega)}{2 \epsilon^{-\frac 1 3} \omega^2  - \frac 1 \epsilon})}$
# ### Si $\omega = 0 \, \Rightarrow \, \phi [T(j\omega)]= 0 $
# ### Si $\omega = \epsilon^{-\frac 1 3} \, \Rightarrow \, \phi [T(j\omega)]= -\frac 3 4 \pi $
# ### Si $\omega \rightarrow \infty \, \Rightarrow \, \phi [T(j\omega)]= -\frac 3 2 \pi$

# %% [markdown]
# ---------------
# # 3)
#
# ### Para implementar esta transferencia pasabajos de orden 3 con estructuras pasivas cascadeo una estructura de orden 1 (R-C serie) con otra de orden 2 (R-L-C serie), ambas pasabajos.
#
# ## $T(s)=\frac {\frac 1 \epsilon}{s^3+2 \epsilon^{-\frac 1 3} s^2 + 2 \epsilon^{-\frac 2 3} s + \frac 1 \epsilon}= \frac {\epsilon^{-\frac 1 3}}{s+\epsilon^{-\frac 1 3}} \,\, \frac{\epsilon^{-\frac 2 3}}{s^2+ \epsilon^{-\frac 1 3} s + \epsilon^{-\frac 2 3}}$
# <br>
#
# ### Orden 1 (R-C serie):
# ## $T_1(s)= \frac {\frac 1{R_1 C_1}} {s+\frac 1 {R_1 C_1}}=\frac {\epsilon^{-\frac 1 3}}{s+\epsilon^{-\frac 1 3}}$
# ### $\Rightarrow \, R_1 C_1=\epsilon^{\frac 1 3} \approx 0.7984 \,\rightarrow \,$ adopto: $\boxed{R_{1_N}=\epsilon^{\frac 1 3}}\, \therefore \,\boxed{C_{1_N}=1}$
# <br>
#
# ### Orden 2 (R-L-C serie):
# ## $T_2(s)= \frac {K\omega_0^2}{s^2+\frac {\omega_0}Q s+\omega_0^2}= \frac {K {\sqrt {\frac 1 {L_2 C_2}}}^2}{s^2+\frac {R_2} {L_2} s+\sqrt {\frac 1 {L_2 C_2}}^2} =\frac{\epsilon^{-\frac 2 3}}{s^2+ \epsilon^{-\frac 1 3} s + \epsilon^{-\frac 2 3}}$
# ### $\Rightarrow \, K=1 \, \land \,\omega_0=\epsilon^{-\frac 1 3} \, \land \,Q=1\,\,$ y los componentes:
# ### $\sqrt {\frac 1 {L_2 C_2}}=\omega_0=\epsilon^{-\frac 1 3}\,\rightarrow \,$ adopto: $\boxed{C_{2_N=1}} \, \therefore \, \boxed{L_{2_N}=\epsilon^{\frac 2 3}}$
# ### $\frac {R_2}{L_2}=\frac {\omega_0} Q = \epsilon^{-\frac 1 3} \, \Rightarrow \boxed{R_{2_N}=\epsilon^{\frac 1 3}}$
# ### y de esta forma $C_{1_N} = C_{2_N} = C_N = 1\,\,$ ; $\,\,R_{1_N} = R_{2_N} = R_N = \epsilon^{\frac 1 3}\,\,$ y $\,\, L_{2_N}=L_N=R_N^2=\epsilon^{\frac 2 3}\,\,$ (recordar que todos estos valores son normalizados)

# %% [markdown]
# --------------
# ## **Simulación del circuito normalizado con LTspice**

# %% [markdown]
# <img src="Simulaciones/Simu_TS3_circ.png" align="center"/>
# <img src="Simulaciones/Simu_TS3_bode.png" align="center"/>
#
# ##### Aclaración: el eje de abscisas es $\omega$

# %% [markdown]
# ---------------
# # 4)
#
# ### Desmormalizo en frecuencia con $\Omega_\omega=2\pi\,1500 \frac {rad} {seg}$
# ### y en impedancia como deseo que $\boxed{C=100nF}=\frac {C_N}{\Omega_\omega \Omega_Z}  \,\Rightarrow \, \Omega_Z=1061,03 \, \Omega$
# ### $R = R_N * \Omega_Z = \epsilon^{\frac 1 3} \,1061,03 \,\Omega \,\Rightarrow \, \boxed{R = 847 \,\Omega} $
# ### $L = \frac {L_N * \Omega_Z}{\Omega_\omega} = \frac {\epsilon^{\frac 2 3} \, 1063,03 \Omega}{2\pi\,1500 \frac {rad} {seg}} \,\Rightarrow \, \boxed{L = 71,9 \,m Hy}$

# %% [markdown]
# -------------------
# ## **Simulación del circuito desnormalizado con LTspice**

# %% [markdown]
# <img src="Simulaciones/Simu_TS3_desnormalizado_circ.png" align="center"/>
# <img src="Simulaciones/Simu_TS3_desnormalizado_bode.png" align="center"/>
#
# ##### Aclaración: el eje de abscisas es frecuencia [Hz]

# %% [markdown]
# ---------------
# # 5)
#
# ### Para evitar utilizar un inductor (no viable en circuitos integrados) puedo:
# ### - Reemplazar dicho inductor por un circuito GIC que simule una inductancia activa ($Z_1, \,Z_2,\, Z_3 y \,Z_5\,$ resistores y $Z_4$ capacitor)
# <br>
#
# ![1.png](attachment:1.png)

# %% [markdown]
# ### - Realizar una transformación de Bruton del circuito pasivo de 2do orden (R-L-C serie) donde finalmente quedaré con otro resistor, otro capacitor y un FDNR (resistor negativo dependiente de la frecuencia) siendo este último implementable con el GIC arriba indicado ($Z_1 y \,Z_3\,$ capacitores y $Z_2, Z_4 y \, Z_5$ resistores)

# %% [markdown]
# ### - Reemplazar el circuito pasivo de 2do orden (R-L-C serie) por otro activo, como por ejemplo un Ackerberg-Mossberg (se realizará este último):
# ![ackmoss.png](attachment:ackmoss.png)
# ##### Aclaración: el amplificador operacional U2 tiene las entradas inversora y no inversora permutadas por un error del diagrama circuital.
# <br>
#
# ### $T(s) = -\frac {K\omega_0^2}{s^2+\frac {\omega_0}Q s+\omega_0^2} = -\frac {R_3}{R_1} \, \frac {\frac 1{R_3^2C^2}}{s^2+\frac 1{R_2C}s+\frac 1{R_3^2C^2}}$
# ### Siendo:
# ### $K=\frac {R_3}{R_1}$
# ### $\omega_0=\frac 1{R_3C}$
# ### $Q=\frac {R_2}{R_3}$
# ### Normalizo en impedancia con: $\Omega_Z=R_3 \,\Rightarrow \, \frac {R_3}{\Omega_Z}=\boxed{{R_{3_N}}=1} \,$ por consiguiente:
# ### $K=\frac 1{{R_{1_N}}} \,\Rightarrow\,$ y como $K=1 \,\Rightarrow\, \boxed{R_{1_N}=1}$
# ### $\omega_0=\frac 1{C_N}\,\Rightarrow\,$ y como $\omega_0=\epsilon^{-\frac 1 3} \,\Rightarrow\, \boxed{C_N=\epsilon^{\frac 1 3}}$
# ### $Q={R_{2_N}}\,\Rightarrow\,$ y como $Q=1 \,\Rightarrow\, \boxed{R_{2_N}=1}$
# ### $\,R_4\,$ puede ser elegido arbitrariamente, por ende se asigna: $\boxed{R_{4_N} = 1}$
# ### Desnormalizo con $\Omega_\omega = 2\pi \, 1500 \frac {rad}{seg}$ y en impedancia como deseo por ejemplo que $\boxed{C=100nF}=\frac {C_N}{\Omega_\omega \Omega_Z}  \,\Rightarrow \, \Omega_Z=847,17 \, \Omega$:
# ### $R_1=R_{1_N} \Omega_Z \, \Rightarrow \, \boxed {R_1=847 \,\Omega}$
# ### $R_2=R_{2_N} \Omega_Z \, \Rightarrow \, \boxed {R_2=847 \,\Omega}$
# ### $R_3=R_{3_N} \Omega_Z \, \Rightarrow \, \boxed {R_3=847 \,\Omega}$
# ### $R_4=R_{4_N} \Omega_Z \, \Rightarrow \, \boxed {R_4=847 \,\Omega}$
# <br>
#
# ### $\, \therefore \, R_1 = R_2 = R_3 = R_4 = R = 847 \,\Omega$
# ------------
# ### Por otra parte, del circuito de 1er orden (R-C serie):  $R_N C_N=\epsilon^{\frac 1 3}$
# ### Desmormalizo en frecuencia con $\Omega_\omega=2\pi\,1500 \frac {rad} {seg} \,\Rightarrow\, R C \Omega_\omega=\epsilon^{\frac 1 3} \,\Rightarrow\, R C= \frac{\epsilon^{\frac 1 3}}{\Omega_\omega} = 84,7\, u\,seg$
# ### Si deseo que $\boxed{C=100 \,nF}  \,\Rightarrow\, \boxed{R= 847 \,\Omega}$

# %% [markdown]
# -------------------
# ## **Simulación del circuito desnormalizado de Ackerberg-Mossberg con LTspice**

# %% [markdown]
# <img src="Simulaciones/Simu_TS3_ackmoss_circ.png" align="center"/>
# <img src="Simulaciones/Simu_TS3_ackmoss_bode.png" align="center"/>
#
# ##### Aclaración: el eje de abscisas es frecuencia [Hz]

# %% [markdown]
# <br>
#
# -----------
# <br>
#
# ## **Solución alternativa: Renormalización por $\omega_B$**
# ### $\omega_B=\epsilon^{-\frac 1 n}=\epsilon^{-\frac 1 3}\,$ (ya fue normalizado por $\omega_p$)
# ### $\, \Rightarrow \, |T(j\omega)|^2 = \frac 1{1+ \omega^{6}}  \, \rightarrow \,$ lo trabajo como Butterworth ($\epsilon=1$)
# <br>
#
# ### Polos (tomo los 3 del semiplano izquierdo):
# ### - radio unitario
# ### - equiespaciados en ángulo $\frac \pi n=\frac \pi 3$, un polo en eje $\sigma$ y dos polos complejos conjugados estarán en: $\, \alpha =\pm \frac \pi 3$
# ### $\,\Rightarrow\, \boxed {p_1: \, s=-1}\,\, \boxed {p_{2;3}: \, s=e^{\pm j\frac \pi 3}}$
# ### $\Rightarrow Q=\frac 1{2\cos (\alpha)}=1$ (el Q se conserva)
# ### $\,T(s)=\frac 1{s+1} \, \frac {\omega_0^2}{s^2+\frac {\omega_0}Q s+\omega_0^2}=\frac 1{s+1} \, \frac 1{s^2+s+1} \, \Rightarrow \, \boxed{T(s)= \frac 1 {s^3+2s^2+2s+1}}$
# ### (donde se puede notar que es la misma transferencia hallada en 1) pero escalada por $\epsilon^{-\frac 1 3}$)

# %% [markdown]
# -----------
# ## **Simulación de función transferencia normalizada con $\omega_B$ con Python**
# <br>
#
# #### Se podrá apreciar que ahora los polos están sobre la circunferencia unitaria (condición necesaria de un Butterworth)

# %%
num = np.array([1]) 
den = np.array([1,2,2,1])

TS = sig.TransferFunction(num,den)

_, axes_hdl = bodePlot(TS)

plt.sca(axes_hdl[0])
plt.ylim([-120,0])

plt.gca

pzmap(TS)

GroupDelay(TS)

plt.show()

# %% [markdown]
# ### Lo implemento utilizando el mismo circuito pasivo de 3) pero recalculando los componentes
# <br>
#
# ## $T(s)=\frac 1 {s^3+2s^2+2s+1}= \frac 1{s+1} \,\, \frac 1{s^2+s+1}$
# <br>
#
# ### Orden 1 (R-C serie):
# ## $T_1(s)= \frac {\frac 1{R_1 C_1}} {s+\frac 1 {R_1 C_1}}= \frac 1 {s+1}$
# ### $\Rightarrow \, R_1 C_1=1 \,\rightarrow \,$ adopto: $\boxed{R_{1_N}=1}\, \therefore \,\boxed{C_{1_N}=1}$
# <br>
#
# ### Orden 2 (R-L-C serie):
# ## $T_2(s)= \frac {K\omega_0^2}{s^2+\frac {\omega_0}Q s+\omega_0^2}= \frac {K {\sqrt {\frac 1 {L_2 C_2}}}^2}{s^2+\frac {R_2} {L_2} s+\sqrt {\frac 1 {L_2 C_2}}^2} =\frac 1{s^2+s+1}$
# ### $\Rightarrow \, K=1 \, \land \,\omega_0=1 \, \land \,Q=1\,\,$ y los componentes:
# ### $\sqrt {\frac 1 {L_2 C_2}}=\omega_0=1\,\rightarrow \,$ adopto: $\boxed{C_{2_N=1}} \, \therefore \, \boxed{L_{2_N}=1}$
# ### $\frac {R_2}{L_2}=\frac {\omega_0} Q = 1 \, \Rightarrow \boxed{R_{2_N}=1}$

# %% [markdown]
# --------------
# ## **Simulación del circuito normalizado por $\omega_B$ con LTspice**

# %% [markdown]
# <img src="Simulaciones/Simu_TS3_butter_circ.png" align="center"/>
# <img src="Simulaciones/Simu_TS3_butter_bode.png" align="center"/>
#
# ##### Aclaración: el eje de abscisas es $\omega$
