# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II - R4052 - 2023
#
# # Trabajo Semanal 6
# #### Autor: Victor Rodolfo Gerez (146.766-9)

# %% [markdown]
# ----------
# <br>
#
# **1)** Se debe diseñar un filtro pasa-altos, que presente máxima planicidad en la banda de paso (frecuencia de corte = 300 Hz) y un cero de transmisión en 100 Hz. El prototipo pasabajos normalizado presenta la siguiente respuesta:
#
# ![imagen.png](attachment:imagen.png)
#
# **a)** Determine la expresión de H(s) del filtro pasa-altos normalizado
# **b)** Realizar el diagrama de polos y ceros de H(s)
# **c)** Sintetice el circuito del filtro pedido. Se utilizará para la estructura de segundo orden el
# siguiente circuito:
# <br>
#
# ![imagen-2.png](attachment:imagen-2.png)
# <br>
#
# **d)** Compare la estructura sugerida y discuta las similitudes y diferencias con la red propuesta por Schaumann:
# <br>
#
# ![imagen-3.png](attachment:imagen-3.png)

# %% [markdown]
# ---------------
# # 1)

# %%
from IPython.display import IFrame
IFrame("TS6_Gerez.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="TS6_Gerez.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# -----------------
# ## **Simulación de función transferencia pasa bajos normalizada con Python**

# %% [markdown]
# Cargo librerías:

# %%
# módulos numéricos y de funciones científicas
import numpy as np
from scipy import signal as sig
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import matplotlib as mpl

# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys

# %% [markdown]
# Configuro gráficos:

# %%
plt.figure(1)
plt.close(1)

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# %% [markdown]
# Simulo:

# %%
num = np.array([0,0.19422,0,1.74801]) 
den = np.array([1,2.35169,2.74637,1.74801])

TS6 = sig.TransferFunction(num,den)

analyze_sys(TS6, 'T_LP_N')

plt.show()

# %% [markdown]
# -----------------
# ## **Simulación de función transferencia pasa altos normalizada con Python**

# %% [markdown]
# Simulo:

# %%
num = np.array([1,0,0.11111,0]) 
den = np.array([1,1.57114,1.34535,0.57208])

TS6 = sig.TransferFunction(num,den)

analyze_sys(TS6, 'T_HP_N')

plt.show()

# %% [markdown]
# --------------
# ## **Simulación del circuito desnormalizado con LTspice**

# %% [markdown]
# <img src="Simulaciones/Simu_TS6_circ.png" align="center"/>
# <img src="Simulaciones/Simu_TS6_bode.png" align="center"/>
